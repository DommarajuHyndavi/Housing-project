# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Hosuing-project-test-data.csv')
df.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL         86.0    14157   Pave   NaN      IR1
# 1  1018         120       RL          NaN     5814   Pave   NaN      IR1
# 2   929          20       RL          NaN    11838   Pave   NaN      Reg
# 3  1148          70       RL         75.0    12000   Pave   NaN      Reg
# 4  1227          60       RL         86.0    14598   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC Fence MiscFeature  \
# 0         HLS    AllPub  ...           0        0    NaN   NaN         NaN
# 1         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 2         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 3         Bnk    AllPub  ...           0        0    NaN   NaN         NaN
# 4         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
# for whole dataframe
df = df.replace(np.nan, 0)

# %%
df.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL         86.0    14157   Pave     0      IR1
# 1  1018         120       RL          0.0     5814   Pave     0      IR1
# 2   929          20       RL          0.0    11838   Pave     0      Reg
# 3  1148          70       RL         75.0    12000   Pave     0      Reg
# 4  1227          60       RL         86.0    14598   Pave     0      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC Fence MiscFeature  \
# 0         HLS    AllPub  ...           0        0    0.0     0           0
# 1         Lvl    AllPub  ...           0        0    0.0     0           0
# 2         Lvl    AllPub  ...           0        0    0.0     0           0
# 3         Bnk    AllPub  ...           0        0    0.0     0           0
# 4         Lvl    AllPub  ...           0        0    0.0     0           0
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
df['LotFrontage'].fillna(df['LotFrontage'].mean(), inplace = True)

# %%
df.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL         86.0    14157   Pave     0      IR1
# 1  1018         120       RL          0.0     5814   Pave     0      IR1
# 2   929          20       RL          0.0    11838   Pave     0      Reg
# 3  1148          70       RL         75.0    12000   Pave     0      Reg
# 4  1227          60       RL         86.0    14598   Pave     0      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC Fence MiscFeature  \
# 0         HLS    AllPub  ...           0        0    0.0     0           0
# 1         Lvl    AllPub  ...           0        0    0.0     0           0
# 2         Lvl    AllPub  ...           0        0    0.0     0           0
# 3         Bnk    AllPub  ...           0        0    0.0     0           0
# 4         Lvl    AllPub  ...           0        0    0.0     0           0
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
df['Alley'].fillna(df['Alley'].mode().values[0], inplace = True)

# %%
df.isnull()
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0    False       False     False        False    False   False  False
# 1    False       False     False        False    False   False  False
# 2    False       False     False        False    False   False  False
# 3    False       False     False        False    False   False  False
# 4    False       False     False        False    False   False  False
# ..     ...         ...       ...          ...      ...     ...    ...
# 287  False       False     False        False    False   False  False
# 288  False       False     False        False    False   False  False
# 289  False       False     False        False    False   False  False
# 290  False       False     False        False    False   False  False
# 291  False       False     False        False    False   False  False
#
#      LotShape  LandContour  Utilities  ...  ScreenPorch  PoolArea  PoolQC  \
# ...

# %%
df['MasVnrType'].fillna(df['MasVnrType'].mode().values[0], inplace = True)

# %%
df['MasVnrArea'].fillna(df['MasVnrArea'].mean(), inplace = True)

# %%
df['BsmtQual'].fillna(df['BsmtQual'].mode().values[0], inplace = True)

# %%
df['BsmtCond'].fillna(df['BsmtCond'].mode().values[0], inplace = True)

# %%
df['BsmtExposure'].fillna(df['BsmtExposure'].mode().values[0], inplace = True)

# %%
df['BsmtFinType1'].fillna(df['BsmtFinType1'].mode().values[0], inplace = True)

# %%
df['BsmtFinType2'].fillna(df['BsmtFinType2'].mode().values[0], inplace = True)

# %%
df['FireplaceQu'].fillna(df['FireplaceQu'].mode().values[0], inplace = True)

# %%
df['GarageType'].fillna(df['GarageType'].mode().values[0], inplace = True)

# %%
df['GarageYrBlt'].fillna(df['GarageYrBlt'].mean(), inplace = True)

# %%
df['GarageFinish'].fillna(df['GarageFinish'].mode().values[0], inplace = True)

# %%
df['GarageQual'].fillna(df['GarageQual'].mode().values[0], inplace = True)

# %%
df['GarageCond'].fillna(df['GarageCond'].mode().values[0], inplace = True)

# %%
df['PoolQC'].fillna(df['PoolQC'].mean(), inplace = True)

# %%
df['Fence'].fillna(df['Fence'].mode().values[0], inplace = True)

# %%
df['MiscFeature'].fillna(df['MiscFeature'].mode().values[0], inplace = True)

# %%
df.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MiscVal          0
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# Length: 80, dtype: int64

# %%
plt.scatter(df['LotShape'],df['LotArea'],color='yellow')
plt.xlabel('Lot Shape')
plt.show()

# %%
plt.scatter(df['LandSlope'],df['LotShape'],color='blue')
plt.xlabel('LandSlope')
plt.ylabel('LotShape')
plt.show()

# %%
plt.scatter(df['LandContour'],df['HouseStyle'],color='blue')
plt.xlabel('LandContour')
plt.ylabel('HouseStyle')
plt.show()

# %%
plt.hist(df['OverallQual'])
plt.xlabel('Rates the overall material and finish of the house')
plt.ylabel('Count')
plt.show()

# %%
plt.hist(df['OverallCond'])
plt.xlabel('Rates the overall condition of the house')
plt.ylabel('Count')
plt.show()

# %%
plt.bar(df['YearRemodAdd'],df['RoofStyle'],)
plt.show()

# %%
plt.bar(df['RoofMatl'],df['RoofStyle'])
plt.show()

# %%
plt.hist(df['RoofStyle'])
plt.show()

# %%
df['MSZoning'].unique()
# Out:
# array(['RL', 'RM', 'FV', 'C (all)'], dtype=object)

# %%
plt.pie(df['MSZoning'].value_counts(),labels = df['MSZoning'].value_counts().index,autopct = '%0.0f')
plt.show()

# %%
plt.scatter(df['ExterQual'].value_counts().index,df['ExterQual'].value_counts(),color = 'red',label = 'ExterQual')
plt.scatter(df['ExterCond'].value_counts().index,df['ExterCond'].value_counts(),color = 'green',label = 'ExterCond')
plt.xlabel('Feed Back')
plt.ylabel('Count')
plt.legend()
plt.show()

# %%
plt.pie(df['Foundation'].value_counts(),labels = df['Foundation'].value_counts().index,autopct = '%0.0f')
plt.show()

# %%
plt.pie(df['BsmtCond'].value_counts(),labels = df['BsmtCond'].value_counts().index)
plt.show()

# %%
plt.pie(df['BsmtQual'].value_counts(),labels = df['BsmtQual'].value_counts().index)
plt.show()

# %%
plt.bar(df['Heating'],df['HeatingQC'])
plt.show()

# %%
plt.pie(df['CentralAir'].value_counts(),labels = df['CentralAir'].value_counts().index)
plt.show()

# %%
plt.pie(df['Electrical'].value_counts(),labels = df['Electrical'].value_counts().index,shadow = True, explode = [0,0,0.2,0.2,0],autopct = '%0.0f')
plt.show()

# %%
plt.plot(df['TotRmsAbvGrd'].value_counts().index,df['TotRmsAbvGrd'].value_counts())
plt.show()

# %%
plt.plot(df['Functional'].value_counts().index,df['Functional'].value_counts(),color = 'violet')
plt.show()

# %%
plt.bar(df['Functional'].value_counts().index,df['Functional'].value_counts(),color = 'violet')
plt.show()

# %%
plt.hist(df['Fireplaces'])
plt.show()

# %%
plt.scatter(df['Fireplaces'].value_counts().index,df['Fireplaces'].value_counts(),color = 'orange')
plt.show()

# %%
plt.pie(df['GarageType'].value_counts(),labels = df['GarageType'].value_counts().index)
plt.show()

# %%
#plt.pie(df['GarageQual'].value_counts(),labels = df['GarageQual'].value_counts().index)
plt.pie(df['GarageQual'].value_counts(),labels = df['GarageQual'].value_counts().index)
plt.show()

# %%
plt.figure(figsize = (5,5))
plt.bar(df['YrSold'],df['MoSold'],width = 0.3, label = 'Houses that are sold in months and years')
plt.xlabel('Year')
plt.ylabel('Month')
plt.show()

# %%
plt.pie(df['SaleCondition'].value_counts(),labels = df['SaleCondition'].value_counts().index)
plt.show()

# %%
hosuing = sns.load_dataset('Hosuing-project-test-data')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 hosuing = sns.load_dataset('Hosuing-project-test-data')
#
# File ~\anaconda3\Lib\site-packages\seaborn\utils.py:587, in load_dataset(name, cache, data_home, **kws)
#     585 if not os.path.exists(cache_path):
#     586     if name not in get_dataset_names():
# --> 587         raise ValueError(f"'{name}' is not one of the example datasets.")
#     588     urlretrieve(url, cache_path)
#     589 full_path = cache_path
#
# ValueError: 'Hosuing-project-test-data' is not one of the example datasets.

# %%
sns.distplot(df['YrSold'], bins= 20)
plt.show()

# %%
y = df['YrSold'] - df['YearBuilt']

# %%
sns.scatterplot(x = df['YearBuilt'],y = y,label = 'Age of the House')
plt.legend()
plt.show()

# %%
z = df['YrSold'] - df['YearRemodAdd']
sns.scatterplot(x = df['YrSold'],y = z,label = 'Remodeled Age')
plt.legend()
plt.show()
